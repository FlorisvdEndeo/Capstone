# %%
import matplotlib.pyplot as plt
import numpy as np



set1 = [-0.6895405447370668, 0.073564563599667, -0.4275550934302825, -0.4713967368259977, -0.6895405447370672, -0.17096188876030172, -0.33688985339221994, -0.04906767432741801, -0.6895405447370668, -0.5956993044924335, -0.4928981922297839, -0.17096188876030124, -0.4496113296546067, -0.6715589548470187]
set2 = [-0.6895405447370668, 0.07356456359966745, -0.42755509343028186, 0.07356456359966745, -0.44961132965460693, -0.12241067519921617, 0.073564563599667, -0.4496113296546067, -0.17096188876030172, -0.44961132965460693, -0.12241067519921617, -0.12241067519921596, 0.073564563599667, -0.47139673682599786]
set3 = [-0.6895405447370672, 0.07356456359966745, -0.4275550934302825, 0.07356456359966745, -0.4496113296546067, -0.47139673682599786, -1.8369701987210297e-16, -0.47139673682599786, -0.47139673682599786, -1.8369701987210297e-16, -0.42755509343028186, -0.17096188876030124, -0.47139673682599786, 6.123233995736766e-17]
set4 = [-0.68615876, -0.08669864, -0.13392591, -0.1764226,  -0.3275584,  -0.13392591,
 -0.1764226,  -0.4619599,  -0.43027061, -0.43027061, -0.4619599,  -0.46427707,
 -0.46427707, -0.4619599 ]

bigset = [-0.6895405447370668, 0.073564563599667, -0.4275550934302825, 0.073564563599667, -0.44961132965460693, -0.12241067519921617, -0.6895405447370672, -0.47139673682599786, -0.1950903220161282, 0.07356456359966745, -0.17096188876030124, -0.42755509343028186, -0.44961132965460693, -1.8369701987210297e-16, -0.6895405447370672, 0.073564563599667, -0.42755509343028186, 0.07356456359966745, -0.4496113296546067, -0.47139673682599786, 6.123233995736766e-17, -0.47139673682599786, -0.4713967368259977, 0.073564563599667, -0.4713967368259977, -0.42755509343028186, -0.4496113296546067, 6.123233995736766e-17, -0.6895405447370668, 0.07356456359966745, -0.4496113296546067, -0.14673047445536233, -0.5349976198870973, -0.4275550934302825, -0.47139673682599786, -0.12241067519921617, -1.8369701987210297e-16, -0.4713967368259977, -1.8369701987210297e-16, -0.4496113296546067, 0.073564563599667, -0.40524131400499036, -0.6895405447370672, 0.07356456359966745, -0.47139673682599786, -0.47139673682599786, -1.8369701987210297e-16, -0.14673047445536164, -0.6895405447370672, -0.17096188876030172, -0.5141027441932219, -0.6895405447370668, -0.31368174039889146, -0.12241067519921596, -0.07356456359966734, -0.2902846772544624]

allsets = set1+set2+set3+set4 + bigset

count10 = [-0.6850836677727005, 0.07356456359966745, -0.47679923006332214, -0.08579731234443977, -0.4605387109582401, -0.13458070850712636, -1.8369701987210297e-16, -0.4605387109582401, -0.4605387109582401, -1.8369701987210297e-16, -0.43309381885315196, -0.38834504669882663, -0.680600997795453, -0.32531029216226287, -0.6850836677727002, 0.07356456359966745, -0.4330938188531521, 0.07968243797143033, -0.4605387109582399, -0.4605387109582401, 0.07968243797143033, -0.4605387109582399, -0.1345807085071261, -0.6850836677727005, -0.4659764957679666, -0.13458070850712636, 6.123233995736766e-17, -0.4605387109582399, -0.6850836677727002, 0.07968243797143013, -0.465976495767966, -0.1345807085071261, -0.4605387109582401, -0.17700422041214875, -1.8369701987210297e-16, -0.43309381885315196, -0.32531029216226287, -0.08579731234444021, -0.4605387109582401, -0.4386162385385276, -0.4605387109582401, 6.123233995736766e-17, -0.6850836677727005, 0.073564563599667, -0.4275550934302825, -0.6850836677727005, -0.4605387109582401, -0.177004220412149, -0.08579731234443977, -0.4275550934302825, -0.177004220412149, -0.4605387109582399, -0.6850836677727002, -0.465976495767966, -0.08579731234443977, -0.465976495767966]

superpos = [-0.44961132965460693, -0.47139673682599786, -0.47139673682599786, -0.47139673682599786, -0.47139673682599786, -0.47139673682599786, -0.40524131400499036, -0.44961132965460693, -0.47139673682599786, -0.47139673682599786, -0.47139673682599786, -0.47139673682599786, -0.47139673682599786, -0.4275550934302825, -0.44961132965460693, -0.47139673682599786, -0.44961132965460693, -0.47139673682599786, -0.47139673682599786]

print(min(superpos))
fig, ax = plt.subplots()
ax.set_xlabel("Hydrogen Energy (Ha)")
ax.set_ylabel("Occurence")
plt.hist(superpos)
plt.show
# Out:
# -0.47139673682599786
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from copy import deepcopy
import math
import matplotlib.pyplot as plt
import scipy.sparse.linalg as spsl
import numpy
import projectq
from projectq import MainEngine
from projectq.backends._sim._simulator import Simulator
from projectq.meta import Compute, Control, Dagger, Uncompute
from projectq.ops import All, H, Measure, Ph, QubitOperator, R, StatePreparation, X, Z
from projectq.backends import CircuitDrawer
from projectq.setups.default import get_engine_list
from projectq.backends import CircuitDrawerMatplotlib
mpl = CircuitDrawerMatplotlib()
drawing_engine = CircuitDrawer()
num_qubits = 1
#
hamiltonian = QubitOperator()
hamiltonian += QubitOperator("", 1)
hamiltonian += QubitOperator("Z0",  0.1)


print(hamiltonian)
hamiltonian_norm = 0.
for term in hamiltonian.terms:
    hamiltonian_norm += abs(hamiltonian.terms[term])
normalized_hamiltonian = deepcopy(hamiltonian)
normalized_hamiltonian /= hamiltonian_norm
#
# def get_eigenvalue_and_eigenvector(n_sites, hamiltonian, k, which='SA'):
#     """
#     Returns k eigenvalues and eigenvectors of the hamiltonian.
#
#     Args:
#         n_sites(int): Number of qubits/sites in the hamiltonian
#         hamiltonian(QubitOperator): QubitOperator representating the Hamiltonian
#         k: num of eigenvalue and eigenvector pairs (see spsl.eigsh k)
#         which: see spsl.eigsh which
#
#     """
#     def mv(v):
#         eng = MainEngine(backend = Simulator() , engine_list = get_engine_list() + [drawing_engine])
#         qureg = eng.allocate_qureg(n_sites)
#         eng.flush()
#         eng.backend.set_wavefunction(v, qureg)
#         eng.backend.apply_qubit_operator(hamiltonian, qureg)
#         order, output = deepcopy(eng.backend.cheat())
#         for i in order:
#             assert i == order[i]
#         eng.backend.set_wavefunction([1]+[0]*(2**n_sites-1), qureg)
#         return output
#
#     A = spsl.LinearOperator((2**n_sites,2**n_sites), matvec=mv)
#
#     eigenvalues, eigenvectormatrix = spsl.eigsh(A, k=k, which=which)
#     eigenvectors = []
#     for i in range(k):
#         eigenvectors.append(list(eigenvectormatrix[:, i]))
#     return eigenvalues, eigenvectors
#
#
# eigenvalues, eigenvectors = get_eigenvalue_and_eigenvector(
#     n_sites=num_qubits,
#     hamiltonian=normalized_hamiltonian,
#     k=1)
# print(eigenvalues)


eigenvalues = [0.5]
eigenvectors = [0, 0]

def W(eng, individual_terms, initial_wavefunction, ancilla_qubits, system_qubits):
    """
    Applies the W operator as defined in arXiv:1711.11025.

    Args:
        eng(MainEngine): compiler engine
        individual_terms(list<QubitOperator>): list of individual unitary
                                               QubitOperators. It applies
                                               individual_terms[0] if ancilla
                                               qubits are in state |0> where
                                               ancilla_qubits[0] is the least
                                               significant bit.
        initial_wavefunction: Initial wavefunction of the ancilla qubits
        ancilla_qubits(Qureg): ancilla quantum register in state |0>
        system_qubits(Qureg): system quantum register
    """
    # Apply V:
    for ancilla_state in range(len(individual_terms)):
        with Compute(eng):
            for bit_pos in range(len(ancilla_qubits)):
                if not (ancilla_state >> bit_pos) & 1:
                    X | ancilla_qubits[bit_pos]
        with Control(eng, ancilla_qubits):
            individual_terms[ancilla_state] | system_qubits
        Uncompute(eng)
    # Apply S: 1) Apply B^dagger
    with Compute(eng):
        with Dagger(eng):
            StatePreparation(initial_wavefunction) | ancilla_qubits
    # Apply S: 2) Apply I-2|0><0|
    with Compute(eng):
        All(X) | ancilla_qubits
    with Control(eng, ancilla_qubits[:-1]):
        Z | ancilla_qubits[-1]
    Uncompute(eng)
    # Apply S: 3) Apply B
    Uncompute(eng)
    # Could also be omitted and added when calculating the eigenvalues:
    Ph(math.pi) | system_qubits[0]

eng = projectq.MainEngine(mpl)
system_qubits = eng.allocate_qureg(num_qubits)
# Create a normalized equal superposition of the two eigenstates for numerical testing:

initial_state_norm =0.
initial_state = eigenvectors
normalized_initial_state = initial_state
# for amplitude in initial_state:
#     initial_state_norm += abs(amplitude)**2
# normalized_initial_state = [amp / math.sqrt(initial_state_norm) for amp in initial_state]

#initialize system qubits in this state:
StatePreparation(normalized_initial_state) | system_qubits


individual_terms = []
initial_ancilla_wavefunction = []
for term in normalized_hamiltonian.terms:
    coefficient = normalized_hamiltonian.terms[term]
    initial_ancilla_wavefunction.append(math.sqrt(abs(coefficient)))
    if coefficient < 0:
        individual_terms.append(QubitOperator(term, -1))
    else:
        individual_terms.append(QubitOperator(term))

# Calculate the number of ancilla qubits required and pad
# the ancilla wavefunction with zeros:
num_ancilla_qubits = int(math.ceil(math.log(len(individual_terms), 2)))
required_padding = 2**num_ancilla_qubits - len(initial_ancilla_wavefunction)
initial_ancilla_wavefunction.extend([0]*required_padding)

# Initialize ancillas by applying B
ancillas = eng.allocate_qureg(num_ancilla_qubits)
StatePreparation(initial_ancilla_wavefunction) | ancillas


# Semiclassical iterative phase estimation
bits_of_precision = 1
pe_ancilla = eng.allocate_qubit()

measurements = [0] * bits_of_precision

for k in range(bits_of_precision):
    H | pe_ancilla
    with Control(eng, pe_ancilla):
        for i in range(2**(bits_of_precision-k-1)):
            W(eng=eng,
              individual_terms=individual_terms,
              initial_wavefunction=initial_ancilla_wavefunction,
              ancilla_qubits=ancillas,
              system_qubits=system_qubits)

    #inverse QFT using one qubit
    for i in range(k):
        if measurements[i]:
            R(-math.pi/(1 << (k - i))) | pe_ancilla

    H | pe_ancilla
    Measure | pe_ancilla
    eng.flush()
    measurements[k] = int(pe_ancilla)
    # put the ancilla in state |0> again
    if measurements[k]:
        X | pe_ancilla

est_phase = sum(
    [(measurements[bits_of_precision - 1 - i]*1. / (1 << (i + 1)))
     for i in range(bits_of_precision)])

# print("We measured a phase of {} corresponding to energy {}".format(est_phase, math.cos(2*math.pi*est_phase)*hamiltonian_norm))
# lstofresults.append(math.cos(2*math.pi*est_phase)*hamiltonian_norm)

eng.flush()
print(mpl.draw())

# eng.flush
# print(CircuitDrawer().get_latex())
#eng.backend.get_expectation_value(normalized_hamiltonian, system_qubits)

#!5 control bits:

# [-0.68615876 -0.08669864 -0.13392591 -0.1764226  -0.3275584  -0.43027061
#  -0.46427707 -0.4619599  -0.13392591 -0.1764226  -0.43027061 -0.4619599
#  -0.46427707 -0.4619599 ]
# We measured 0.263824462890625 corresponding to energy -0.0867524755202204

# with Dagger(eng):
#     StatePreparation(initial_ancilla_wavefunction) | ancillas
# measure_qb = eng.allocate_qubit()
# with Compute(eng):
#     All(X) | ancillas
# with Control(eng, ancillas):
#     X | measure_qb
# Uncompute(eng)
# eng.flush()
# eng.backend.get_probability('1', measure_qb)
#
#
# eng.backend.collapse_wavefunction(measure_qb, [1])
# print(eng.backend.get_expectation_value(normalized_hamiltonian, system_qubits))
#
# print(lstofresults)
# sortedresults = sorted(lstofresults)
# fig, ax = plt.subplots()  # Create a figure containing a single axes.
# ax.plot(lstofresults)
# ax.plot(sortedresults)
# plt.hist(sortedresults)
# plt.show
  # Plot some data on the axes.
# Out:
# 1 I +
# 0.1 Z0
# (<Figure size 1282.56x288 with 1 Axes>, <matplotlib.axes._subplots.AxesSubplot object at 0x122acb090>)

# %%
import random
print(random.randrange(57))
# Out:
# 49

# %%
from copy import deepcopy
import math

import scipy.sparse.linalg as spsl

import projectq
from projectq import MainEngine
from projectq.backends._sim._simulator import Simulator
from projectq.meta import Compute, Control, Dagger, Uncompute
from projectq.ops import All, H, Measure, Ph, QubitOperator, R, StatePreparation, X, Z
from projectq.backends import CircuitDrawer
from projectq.setups.default import get_engine_list
import matplotlib.pyplot as plt
from scipy.optimize import minimize_scalar

# Data from paper (arXiv:1512.06860v2) table 1: R, I, Z0, Z1, Z0Z1, X0X1, Y0Y1
raw_data_table_1 = [
    [0.20,  2.8489, 0.5678, -1.4508, 0.6799, 0.0791, 0.0791],
    [0.25,  2.1868, 0.5449, -1.2870, 0.6719, 0.0798, 0.0798],
    [0.30,  1.7252, 0.5215, -1.1458, 0.6631, 0.0806, 0.0806],
    [0.35,  1.3827, 0.4982, -1.0226, 0.6537, 0.0815, 0.0815],
    [0.40,  1.1182, 0.4754, -0.9145, 0.6438, 0.0825, 0.0825],
    [0.45,  0.9083, 0.4534, -0.8194, 0.6336, 0.0835, 0.0835],
    [0.50,  0.7381, 0.4325, -0.7355, 0.6233, 0.0846, 0.0846],
    [0.55,  0.5979, 0.4125, -0.6612, 0.6129, 0.0858, 0.0858],
    [0.60,  0.4808, 0.3937, -0.5950, 0.6025, 0.0870, 0.0870],
    [0.65,  0.3819, 0.3760, -0.5358, 0.5921, 0.0883, 0.0883],
    [0.70,  0.2976, 0.3593, -0.4826, 0.5818, 0.0896, 0.0896],
    [0.75,  0.2252, 0.3435, -0.4347, 0.5716, 0.0910, 0.0910],
    [0.80,  0.1626, 0.3288, -0.3915, 0.5616, 0.0925, 0.0925],
    [0.85,  0.1083, 0.3149, -0.3523, 0.5518, 0.0939, 0.0939],
    [0.90,  0.0609, 0.3018, -0.3168, 0.5421, 0.0954, 0.0954],
    [0.95,  0.0193, 0.2895, -0.2845, 0.5327, 0.0970, 0.0970],
    [1.00, -0.0172, 0.2779, -0.2550, 0.5235, 0.0986, 0.0986],
    [1.05, -0.0493, 0.2669, -0.2282, 0.5146, 0.1002, 0.1002],
    [1.10, -0.0778, 0.2565, -0.2036, 0.5059, 0.1018, 0.1018],
    [1.15, -0.1029, 0.2467, -0.1810, 0.4974, 0.1034, 0.1034],
    [1.20, -0.1253, 0.2374, -0.1603, 0.4892, 0.1050, 0.1050],
    [1.25, -0.1452, 0.2286, -0.1413, 0.4812, 0.1067, 0.1067],
    [1.30, -0.1629, 0.2203, -0.1238, 0.4735, 0.1083, 0.1083],
    [1.35, -0.1786, 0.2123, -0.1077, 0.4660, 0.1100, 0.1100],
    [1.40, -0.1927, 0.2048, -0.0929, 0.4588, 0.1116, 0.1116],
    [1.45, -0.2053, 0.1976, -0.0792, 0.4518, 0.1133, 0.1133],
    [1.50, -0.2165, 0.1908, -0.0666, 0.4451, 0.1149, 0.1149],
    [1.55, -0.2265, 0.1843, -0.0549, 0.4386, 0.1165, 0.1165],
    [1.60, -0.2355, 0.1782, -0.0442, 0.4323, 0.1181, 0.1181],
    [1.65, -0.2436, 0.1723, -0.0342, 0.4262, 0.1196, 0.1196],
    [1.70, -0.2508, 0.1667, -0.0251, 0.4204, 0.1211, 0.1211],
    [1.75, -0.2573, 0.1615, -0.0166, 0.4148, 0.1226, 0.1226],
    [1.80, -0.2632, 0.1565, -0.0088, 0.4094, 0.1241, 0.1241],
    [1.85, -0.2684, 0.1517, -0.0015, 0.4042, 0.1256, 0.1256],
    [1.90, -0.2731, 0.1472,  0.0052, 0.3992, 0.1270, 0.1270],
    [1.95, -0.2774, 0.1430,  0.0114, 0.3944, 0.1284, 0.1284],
    [2.00, -0.2812, 0.1390,  0.0171, 0.3898, 0.1297, 0.1297],
    [2.05, -0.2847, 0.1352,  0.0223, 0.3853, 0.1310, 0.1310],
    [2.10, -0.2879, 0.1316,  0.0272, 0.3811, 0.1323, 0.1323],
    [2.15, -0.2908, 0.1282,  0.0317, 0.3769, 0.1335, 0.1335],
    [2.20, -0.2934, 0.1251,  0.0359, 0.3730, 0.1347, 0.1347],
    [2.25, -0.2958, 0.1221,  0.0397, 0.3692, 0.1359, 0.1359],
    [2.30, -0.2980, 0.1193,  0.0432, 0.3655, 0.1370, 0.1370],
    [2.35, -0.3000, 0.1167,  0.0465, 0.3620, 0.1381, 0.1381],
    [2.40, -0.3018, 0.1142,  0.0495, 0.3586, 0.1392, 0.1392],
    [2.45, -0.3035, 0.1119,  0.0523, 0.3553, 0.1402, 0.1402],
    [2.50, -0.3051, 0.1098,  0.0549, 0.3521, 0.1412, 0.1412],
    [2.55, -0.3066, 0.1078,  0.0572, 0.3491, 0.1422, 0.1422],
    [2.60, -0.3079, 0.1059,  0.0594, 0.3461, 0.1432, 0.1432],
    [2.65, -0.3092, 0.1042,  0.0614, 0.3433, 0.1441, 0.1441],
    [2.70, -0.3104, 0.1026,  0.0632, 0.3406, 0.1450, 0.1450],
    [2.75, -0.3115, 0.1011,  0.0649, 0.3379, 0.1458, 0.1458],
    [2.80, -0.3125, 0.0997,  0.0665, 0.3354, 0.1467, 0.1467],
    [2.85, -0.3135, 0.0984,  0.0679, 0.3329, 0.1475, 0.1475]]



num_qubits = 2

lowest_energies = []
bond_distances = []
for i in range(len(raw_data_table_1)):
    # Use data of paper to construct the Hamiltonian
    bond_distances.append(raw_data_table_1[i][0])
    hamiltonian = raw_data_table_1[i][1] * QubitOperator(())  # == identity
    hamiltonian += raw_data_table_1[i][2] * QubitOperator("Z0")
    hamiltonian += raw_data_table_1[i][3] * QubitOperator("Z1")
    hamiltonian += raw_data_table_1[i][4] * QubitOperator("Z0 Z1")
    hamiltonian += raw_data_table_1[i][5] * QubitOperator("X0 X1")
    hamiltonian += raw_data_table_1[i][6] * QubitOperator("Y0 Y1")



    hamiltonian_norm = 0.
    for term in hamiltonian.terms:
        hamiltonian_norm += abs(hamiltonian.terms[term])
    normalized_hamiltonian = deepcopy(hamiltonian)
    normalized_hamiltonian /= hamiltonian_norm

    def get_eigenvalue_and_eigenvector(n_sites, hamiltonian, k, which='SA'):
        """
        Returns k eigenvalues and eigenvectors of the hamiltonian.

        Args:
            n_sites(int): Number of qubits/sites in the hamiltonian
            hamiltonian(QubitOperator): QubitOperator representating the Hamiltonian
            k: num of eigenvalue and eigenvector pairs (see spsl.eigsh k)
            which: see spsl.eigsh which

        """
        def mv(v):
            eng = projectq.MainEngine(backend=Simulator(), engine_list=[])
            #eng = MainEngine(backend = Simulator() , engine_list = get_engine_list() + [drawing_engine])
            qureg = eng.allocate_qureg(n_sites)
            eng.flush()
            eng.backend.set_wavefunction(v, qureg)
            eng.backend.apply_qubit_operator(hamiltonian, qureg)
            order, output = deepcopy(eng.backend.cheat())
            for i in order:
                assert i == order[i]
            eng.backend.set_wavefunction([1]+[0]*(2**n_sites-1), qureg)
            return output

        A = spsl.LinearOperator((2**n_sites,2**n_sites), matvec=mv)

        eigenvalues, eigenvectormatrix = spsl.eigsh(A, k=k, which=which)
        eigenvectors = []
        for i in range(k):
            eigenvectors.append(list(eigenvectormatrix[:, i]))
        return eigenvalues, eigenvectors


    eigenvalues, eigenvectors = get_eigenvalue_and_eigenvector(
        n_sites=num_qubits,
        hamiltonian=normalized_hamiltonian,
        k=1)
    print(eigenvalues)


    def W(eng, individual_terms, initial_wavefunction, ancilla_qubits, system_qubits):
        """
        Applies the W operator as defined in arXiv:1711.11025.

        Args:
            eng(MainEngine): compiler engine
            individual_terms(list<QubitOperator>): list of individual unitary
                                                   QubitOperators. It applies
                                                   individual_terms[0] if ancilla
                                                   qubits are in state |0> where
                                                   ancilla_qubits[0] is the least
                                                   significant bit.
            initial_wavefunction: Initial wavefunction of the ancilla qubits
            ancilla_qubits(Qureg): ancilla quantum register in state |0>
            system_qubits(Qureg): system quantum register
        """
        # Apply V:
        for ancilla_state in range(len(individual_terms)):
            with Compute(eng):
                for bit_pos in range(len(ancilla_qubits)):
                    if not (ancilla_state >> bit_pos) & 1:
                        X | ancilla_qubits[bit_pos]
            with Control(eng, ancilla_qubits):
                individual_terms[ancilla_state] | system_qubits
            Uncompute(eng)
        # Apply S: 1) Apply B^dagger
        with Compute(eng):
            with Dagger(eng):
                StatePreparation(initial_wavefunction) | ancilla_qubits
        # Apply S: 2) Apply I-2|0><0|
        with Compute(eng):
            All(X) | ancilla_qubits
        with Control(eng, ancilla_qubits[:-1]):
            Z | ancilla_qubits[-1]
        Uncompute(eng)
        # Apply S: 3) Apply B
        Uncompute(eng)
        # Could also be omitted and added when calculating the eigenvalues:
        Ph(math.pi) | system_qubits[0]

    eng = projectq.MainEngine()
    system_qubits = eng.allocate_qureg(num_qubits)

    # Create a normalized equal superposition of the two eigenstates for numerical testing:
    initial_state_norm = 0.
    initial_state = eigenvectors[0]
    for amplitude in initial_state:
        initial_state_norm += abs(amplitude)**2
    normalized_initial_state = [amp / math.sqrt(initial_state_norm) for amp in initial_state]

    #initialize system qubits in this state:
    StatePreparation(normalized_initial_state) | system_qubits


    individual_terms = []
    initial_ancilla_wavefunction = []
    for term in normalized_hamiltonian.terms:
        coefficient = normalized_hamiltonian.terms[term]
        initial_ancilla_wavefunction.append(math.sqrt(abs(coefficient)))
        if coefficient < 0:
            individual_terms.append(QubitOperator(term, -1))
        else:
            individual_terms.append(QubitOperator(term))

    # Calculate the number of ancilla qubits required and pad
    # the ancilla wavefunction with zeros:
    num_ancilla_qubits = int(math.ceil(math.log(len(individual_terms), 2)))
    required_padding = 2**num_ancilla_qubits - len(initial_ancilla_wavefunction)
    initial_ancilla_wavefunction.extend([0]*required_padding)

    # Initialize ancillas by applying B
    ancillas = eng.allocate_qureg(num_ancilla_qubits)
    StatePreparation(initial_ancilla_wavefunction) | ancillas


    # Semiclassical iterative phase estimation
    bits_of_precision = 10
    pe_ancilla = eng.allocate_qubit()

    measurements = [0] * bits_of_precision

    for k in range(bits_of_precision):
        H | pe_ancilla
        with Control(eng, pe_ancilla):
            for i in range(2**(bits_of_precision-k-1)):
                W(eng=eng,
                  individual_terms=individual_terms,
                  initial_wavefunction=initial_ancilla_wavefunction,
                  ancilla_qubits=ancillas,
                  system_qubits=system_qubits)

        #inverse QFT using one qubit
        for i in range(k):
            if measurements[i]:
                R(-math.pi/(1 << (k - i))) | pe_ancilla

        H | pe_ancilla
        Measure | pe_ancilla
        eng.flush()
        measurements[k] = int(pe_ancilla)
        # put the ancilla in state |0> again
        if measurements[k]:
            X | pe_ancilla

    est_phase = sum(
        [(measurements[bits_of_precision - 1 - i]*1. / (1 << (i + 1)))
         for i in range(bits_of_precision)])

    print("R: {} We measured {} corresponding to energy {}".format(raw_data_table_1[i][0], est_phase, math.cos(2*math.pi*est_phase)*hamiltonian_norm))
    lowest_energies.append(math.cos(2*math.pi*est_phase)*hamiltonian_norm)


print(lowest_energies)
print(bond_distances)

plt.xlabel("Bond length [Angstrom]")
plt.ylabel("Total Energy [Hartree]")
plt.title("Spectrum by Quantum walk")
plt.plot(bond_distances, lowest_energies, "b.-",
         label="Ground-state energy of molecular hydrogen")
plt.legend()
plt.show()
#eng.backend.get_expectation_value(normalized_hamiltonian, system_qubits)






#!5 control bits:

# [-0.68615876 -0.08669864 -0.13392591 -0.1764226  -0.3275584  -0.43027061
#  -0.46427707 -0.4619599  -0.13392591 -0.1764226  -0.43027061 -0.4619599
#  -0.46427707 -0.4619599 ]
# We measured 0.263824462890625 corresponding to energy -0.0867524755202204

# with Dagger(eng):
#     StatePreparation(initial_ancilla_wavefunction) | ancillas
# measure_qb = eng.allocate_qubit()
# with Compute(eng):
#     All(X) | ancillas
# with Control(eng, ancillas):
#     X | measure_qb
# Uncompute(eng)
# eng.flush()
# eng.backend.get_probability('1', measure_qb)


# eng.backend.collapse_wavefunction(measure_qb, [1])
# eng.backend.get_expectation_value(normalized_hamiltonian, system_qubits)
# Out:
# [0.02527523]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.75390625 corresponding to energy 0.14002243346032683
# [-0.06678884]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.2607421875 corresponding to energy -0.32711649866768305
# [-0.14536486]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.2734375 corresponding to energy -0.6187330646833691
# [-0.21517936]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.7158203125 corresponding to energy -0.7928130121518452
# [-0.27895312]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.294921875 corresponding to energy -0.9238219577212823
# [-0.33840058]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.3046875 corresponding to energy -1.004504475859582
# [-0.39479426]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.314453125 corresponding to energy -1.063226919308744
# [-0.44881161]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.67578125 corresponding to energy -1.10429038676468
# [-0.50115506]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
# ...
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.412109375 corresponding to energy -0.9424501987675286
# [-0.85162295]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.412109375 corresponding to energy -0.9428758763640813
# [-0.85128871]
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a9ed830>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# R: 0.6 We measured 0.412109375 corresponding to energy -0.9430461474027022
# [0.14002243346032683, -0.32711649866768305, -0.6187330646833691, -0.7928130121518452, -0.9238219577212823, -1.004504475859582, -1.063226919308744, -1.10429038676468, -1.1190193400208674, -1.1352645233844536, -1.1414716190690435, -1.1394398025958514, -1.1451388560930484, -1.1411533192309775, -1.129266438888005, -1.119518855140352, -1.1095290985739632, -1.0995758158199946, -1.0853465127090065, -1.0743834166210366, -1.063420320533067, -1.052544233144208, -1.0451819986645352, -1.0342683114343068, -1.0236165526976033, -1.0166793443137692, -1.006429324211683, -0.9997006051172849, -0.9933961121619872, -0.9869911632997113, -0.9810193084692341, -0.9753975314423078, -0.970130913528449, -0.9678723995523884, -0.9635210536996024, -0.9613137088962908, -0.9582074537144878, -0.9544783676258953, -0.9537689544241402, -0.9523972204675956, -0.9509763220816116, -0.9491605797351752, -0.9435014710002994, -0.9481588462156367, -0.9456457925253, -0.9464177482743003, -0.9436883865519119, -0.944372032942604, -0.9448847677356234, -0.9418542501323549, -0.9422799277289076, -0.9424501987675286, -0.9428758763640813, -0.9430461474027022]
# [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.05, 1.1, 1.15, 1.2, 1.25, 1.3, 1.35, 1.4, 1.45, 1.5, 1.55, 1.6, 1.65, 1.7, 1.75, 1.8, 1.85, 1.9, 1.95, 2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.5, 2.55, 2.6, 2.65, 2.7, 2.75, 2.8, 2.85]

# %%
from copy import deepcopy
import math
import matplotlib.pyplot as plt
import scipy.sparse.linalg as spsl
import numpy
import projectq
from projectq import MainEngine
from projectq.backends._sim._simulator import Simulator
from projectq.meta import Compute, Control, Dagger, Uncompute
from projectq.ops import All, H, Measure, Ph, QubitOperator, R, StatePreparation, X, Z
from projectq.backends import CircuitDrawer


num_qubits = 4
count = 0
hamiltonian = QubitOperator()
hamiltonian += QubitOperator("", -0.81261)
hamiltonian += QubitOperator("Z0",  0.171201)
hamiltonian += QubitOperator("Z1", 0.16862325)
hamiltonian += QubitOperator("Z2", -0.2227965)
hamiltonian += QubitOperator("Z1 Z0",  0.171201)
hamiltonian += QubitOperator("Z2 Z0", 0.12054625)
hamiltonian += QubitOperator("Z3 Z1", 0.17434925)
hamiltonian += QubitOperator("X2 Z1 X0", 0.04532175)
hamiltonian += QubitOperator("Y2 Z1 Y0", 0.04532175)
hamiltonian += QubitOperator("Z2 Z1 Z0", 0.165868)
hamiltonian += QubitOperator("Z3 Z2 Z0", 0.12054625)
hamiltonian += QubitOperator("Z3 Z2 Z1", -0.2227965)
hamiltonian += QubitOperator("Z3 X2 Z1 X0", 0.04532175)
hamiltonian += QubitOperator("Z3 Y2 Z1 Y0", 0.04532175)
hamiltonian += QubitOperator("Z3 Z2 Z1 Z0", 0.165868)

# print(hamiltonian)
hamiltonian_norm = 0.
for term in hamiltonian.terms:
    hamiltonian_norm += abs(hamiltonian.terms[term])
normalized_hamiltonian = deepcopy(hamiltonian)
normalized_hamiltonian /= hamiltonian_norm

#print(hamiltonian_norm)
def get_eigenvalue_and_eigenvector(n_sites, hamiltonian, k, which='SA'):
    """
    Returns k eigenvalues and eigenvectors of the hamiltonian.

    Args:
        n_sites(int): Number of qubits/sites in the hamiltonian
        hamiltonian(QubitOperator): QubitOperator representating the Hamiltonian
        k: num of eigenvalue and eigenvector pairs (see spsl.eigsh k)
        which: see spsl.eigsh which

    """
    def mv(v):
        eng = projectq.MainEngine(backend=Simulator(), engine_list=[])
        qureg = eng.allocate_qureg(n_sites)
        eng.flush()
        eng.backend.set_wavefunction(v, qureg)
        eng.backend.apply_qubit_operator(hamiltonian, qureg)
        order, output = deepcopy(eng.backend.cheat())
        for i in order:
            assert i == order[i]
        eng.backend.set_wavefunction([1]+[0]*(2**n_sites-1), qureg)
        return output

    A = spsl.LinearOperator((2**n_sites,2**n_sites), matvec=mv)

    eigenvalues, eigenvectormatrix = spsl.eigsh(A, k=k, which=which)
    eigenvectors = []
    for i in range(k):
        eigenvectors.append(list(eigenvectormatrix[:, i]))
    return eigenvalues, eigenvectors

lstofresults = []


eigenvalues, eigenvectors = get_eigenvalue_and_eigenvector(
    n_sites=num_qubits,
    hamiltonian=normalized_hamiltonian,
    k=13)
#print(eigenvalues)


def W(eng, individual_terms, initial_wavefunction, ancilla_qubits, system_qubits):
    """
    Applies the W operator as defined in arXiv:1711.11025.

    Args:
        eng(MainEngine): compiler engine
        individual_terms(list<QubitOperator>): list of individual unitary
                                               QubitOperators. It applies
                                               individual_terms[0] if ancilla
                                               qubits are in state |0> where
                                               ancilla_qubits[0] is the least
                                               significant bit.
        initial_wavefunction: Initial wavefunction of the ancilla qubits
        ancilla_qubits(Qureg): ancilla quantum register in state |0>
        system_qubits(Qureg): system quantum register
    """
    # Apply V:
    for ancilla_state in range(len(individual_terms)):
        with Compute(eng):
            for bit_pos in range(len(ancilla_qubits)):
                if not (ancilla_state >> bit_pos) & 1:
                    X | ancilla_qubits[bit_pos]
        with Control(eng, ancilla_qubits):
            individual_terms[ancilla_state] | system_qubits
        Uncompute(eng)
    # Apply S: 1) Apply B^dagger
    with Compute(eng):
        with Dagger(eng):
            StatePreparation(initial_wavefunction) | ancilla_qubits
    # Apply S: 2) Apply I-2|0><0|
    with Compute(eng):
        All(X) | ancilla_qubits
    with Control(eng, ancilla_qubits[:-1]):
        Z | ancilla_qubits[-1]
    Uncompute(eng)
    # Apply S: 3) Apply B
    Uncompute(eng)
    # Could also be omitted and added when calculating the eigenvalues:
    Ph(math.pi) | system_qubits[0]

eng = projectq.MainEngine()
system_qubits = eng.allocate_qureg(num_qubits)
# Create a normalized equal superposition of the two eigenstates for numerical testing:

initial_state_norm = 0.
initial_state = [i+j for i,j in zip(eigenvectors[1], eigenvectors[9])]
for amplitude in initial_state:
    initial_state_norm += abs(amplitude)**2
normalized_initial_state = [amp / math.sqrt(initial_state_norm) for amp in initial_state]

#initialize system qubits in this state:
StatePreparation(normalized_initial_state) | system_qubits


individual_terms = []
initial_ancilla_wavefunction = []
for term in normalized_hamiltonian.terms:
    coefficient = normalized_hamiltonian.terms[term]
    initial_ancilla_wavefunction.append(math.sqrt(abs(coefficient)))
    if coefficient < 0:
        individual_terms.append(QubitOperator(term, -1))
    else:
        individual_terms.append(QubitOperator(term))

# Calculate the number of ancilla qubits required and pad
# the ancilla wavefunction with zeros:
num_ancilla_qubits = int(math.ceil(math.log(len(individual_terms), 2)))
required_padding = 2**num_ancilla_qubits - len(initial_ancilla_wavefunction)
initial_ancilla_wavefunction.extend([0]*required_padding)

# Initialize ancillas by applying B
ancillas = eng.allocate_qureg(num_ancilla_qubits)
StatePreparation(initial_ancilla_wavefunction) | ancillas


# Semiclassical iterative phase estimation
bits_of_precision = 8
pe_ancilla = eng.allocate_qubit()

measurements = [0] * bits_of_precision

for k in range(bits_of_precision):
    H | pe_ancilla
    with Control(eng, pe_ancilla):
        for i in range(2**(bits_of_precision-k-1)):
            W(eng=eng,
              individual_terms=individual_terms,
              initial_wavefunction=initial_ancilla_wavefunction,
              ancilla_qubits=ancillas,
              system_qubits=system_qubits)

    #inverse QFT using one qubit
    for i in range(k):
        if measurements[i]:
            R(-math.pi/(1 << (k - i))) | pe_ancilla

    H | pe_ancilla
    Measure | pe_ancilla
    eng.flush()
    measurements[k] = int(pe_ancilla)
    # put the ancilla in state |0> again
    if measurements[k]:
        X | pe_ancilla

est_phase = sum(
    [(measurements[bits_of_precision - 1 - i]*1. / (1 << (i + 1)))
     for i in range(bits_of_precision)])

#print("we measured a phase of {} corresponding to energy {}".format(est_phase, math.cos(2*math.pi*est_phase)))
print(math.cos(2*math.pi*est_phase))
#lstofresults.append(math.cos(2*math.pi*est_phase))
# eng.flush
# print(CircuitDrawer().get_latex())
#eng.backend.get_expectation_value(normalized_hamiltonian, system_qubits)
sigma = QubitOperator()
sigma += QubitOperator("Z0", 0.5)
sigma += QubitOperator("Y2", 0.5)
sigma += QubitOperator("Z1", 0.5)
sigma += QubitOperator("X0", 0.5)

print(eng.backend.get_expectation_value(sigma, system_qubits))

#!5 control bits:

# [-0.68615876 -0.08669864 -0.13392591 -0.1764226  -0.3275584  -0.43027061
#  -0.46427707 -0.4619599  -0.13392591 -0.1764226  -0.43027061 -0.4619599
#  -0.46427707 -0.4619599 ]
# We measured 0.263824462890625 corresponding to energy -0.0867524755202204

with Dagger(eng):
    StatePreparation(initial_ancilla_wavefunction) | ancillas
measure_qb = eng.allocate_qubit()
with Compute(eng):
    All(X) | ancillas
with Control(eng, ancillas):
    X | measure_qb
Uncompute(eng)
eng.flush()
#eng.backend.get_probability('1', measure_qb)

print(system_qubits == eigenvectors[1])
eng.backend.collapse_wavefunction(measure_qb, [1])
print(eng.backend.get_expectation_value(sigma, system_qubits))


#with open("analyze.py", "w") as f:
#    f.write(lstofresults)

# sortedresults = sorted(lstofresults)
# fig, ax = plt.subplots()  # Create a figure containing a single axes.
# ax.plot(lstofresults)
# ax.plot(sortedresults)
# plt.hist(sortedresults)
# plt.show
# Plot some data on the axes.
# Out:
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'
# -0.47139673682599786
# -0.7843169797344984
# False
# -0.8088723062708778
# Exception ignored in: <function Qubit.__del__ at 0x11a544950>
# Traceback (most recent call last):
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/types/_qubit.py", line 135, in __del__
#     self.engine.deallocate_qubit(weak_copy)
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_basics.py", line 153, in deallocate_qubit
#     tags=[DirtyQubitTag()] if is_dirty else [])])
#   File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/cengines/_main.py", line 288, in send
#     raise compact_exception  # use verbose=True for more info
# RuntimeError: Error: Qubit has not been measured / uncomputed! There is most likely a bug in your code.
#  raised in:
# '  File "/Users/floreman/.local/lib/python3.7/site-packages/projectq/backends/_sim/_simulator.py", line 387, in _handle'
# '    self._simulator.deallocate_qubit(ID)'

# %%
lstsuper = [-0.47139673682599786, -0.14673047445536233,-0.14673047445536233, -0.14673047445536233, 
-0.47139673682599786, -0.14673047445536233, -0.14673047445536164, -0.14673047445536233, -0.47139673682599786, -0.47139673682599786, -0.14673047445536164, -0.47139673682599786, -0.47139673682599786]

for item in lstsuper:
    lstsuper.append(item)
    if len(lstsuper)>30:
        break

lstsuper.append(-0.47139673682599786)


plt.hist(lstsuper)
# Out:
# (array([15.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 17.]),
#  array([-0.47139674, -0.43893011, -0.40646348, -0.37399686, -0.34153023,
#         -0.30906361, -0.27659698, -0.24413035, -0.21166373, -0.1791971 ,
#         -0.14673047]),
#  <a list of 10 Patch objects>)

# %%
from copy import deepcopy
import math

import scipy.sparse.linalg as spsl

import projectq
from projectq import MainEngine
from projectq.backends._sim._simulator import Simulator
from projectq.meta import Compute, Control, Dagger, Uncompute
from projectq.ops import All, H, Measure, Ph, QubitOperator, R, StatePreparation, X, Z
from projectq.backends import CircuitDrawer
from projectq.setups.default import get_engine_list
import matplotlib.pyplot as plt
from scipy.optimize import minimize_scalar

# Data from paper (arXiv:1512.06860v2) table 1: R, I, Z0, Z1, Z0Z1, X0X1, Y0Y1
raw_data_table_1 = [
    [0.20,  2.8489, 0.5678, -1.4508, 0.6799, 0.0791, 0.0791],
    [0.25,  2.1868, 0.5449, -1.2870, 0.6719, 0.0798, 0.0798],
    [0.30,  1.7252, 0.5215, -1.1458, 0.6631, 0.0806, 0.0806],
    [0.35,  1.3827, 0.4982, -1.0226, 0.6537, 0.0815, 0.0815],
    [0.40,  1.1182, 0.4754, -0.9145, 0.6438, 0.0825, 0.0825],
    [0.45,  0.9083, 0.4534, -0.8194, 0.6336, 0.0835, 0.0835],
    [0.50,  0.7381, 0.4325, -0.7355, 0.6233, 0.0846, 0.0846],
    [0.55,  0.5979, 0.4125, -0.6612, 0.6129, 0.0858, 0.0858],
    [0.60,  0.4808, 0.3937, -0.5950, 0.6025, 0.0870, 0.0870],
    [0.65,  0.3819, 0.3760, -0.5358, 0.5921, 0.0883, 0.0883],
    [0.70,  0.2976, 0.3593, -0.4826, 0.5818, 0.0896, 0.0896],
    [0.75,  0.2252, 0.3435, -0.4347, 0.5716, 0.0910, 0.0910],
    [0.80,  0.1626, 0.3288, -0.3915, 0.5616, 0.0925, 0.0925],
    [0.85,  0.1083, 0.3149, -0.3523, 0.5518, 0.0939, 0.0939],
    [0.90,  0.0609, 0.3018, -0.3168, 0.5421, 0.0954, 0.0954],
    [0.95,  0.0193, 0.2895, -0.2845, 0.5327, 0.0970, 0.0970],
    [1.00, -0.0172, 0.2779, -0.2550, 0.5235, 0.0986, 0.0986],
    [1.05, -0.0493, 0.2669, -0.2282, 0.5146, 0.1002, 0.1002],
    [1.10, -0.0778, 0.2565, -0.2036, 0.5059, 0.1018, 0.1018],
    [1.15, -0.1029, 0.2467, -0.1810, 0.4974, 0.1034, 0.1034],
    [1.20, -0.1253, 0.2374, -0.1603, 0.4892, 0.1050, 0.1050],
    [1.25, -0.1452, 0.2286, -0.1413, 0.4812, 0.1067, 0.1067],
    [1.30, -0.1629, 0.2203, -0.1238, 0.4735, 0.1083, 0.1083],
    [1.35, -0.1786, 0.2123, -0.1077, 0.4660, 0.1100, 0.1100],
    [1.40, -0.1927, 0.2048, -0.0929, 0.4588, 0.1116, 0.1116],
    [1.45, -0.2053, 0.1976, -0.0792, 0.4518, 0.1133, 0.1133],
    [1.50, -0.2165, 0.1908, -0.0666, 0.4451, 0.1149, 0.1149],
    [1.55, -0.2265, 0.1843, -0.0549, 0.4386, 0.1165, 0.1165],
    [1.60, -0.2355, 0.1782, -0.0442, 0.4323, 0.1181, 0.1181],
    [1.65, -0.2436, 0.1723, -0.0342, 0.4262, 0.1196, 0.1196],
    [1.70, -0.2508, 0.1667, -0.0251, 0.4204, 0.1211, 0.1211],
    [1.75, -0.2573, 0.1615, -0.0166, 0.4148, 0.1226, 0.1226],
    [1.80, -0.2632, 0.1565, -0.0088, 0.4094, 0.1241, 0.1241],
    [1.85, -0.2684, 0.1517, -0.0015, 0.4042, 0.1256, 0.1256],
    [1.90, -0.2731, 0.1472,  0.0052, 0.3992, 0.1270, 0.1270],
    [1.95, -0.2774, 0.1430,  0.0114, 0.3944, 0.1284, 0.1284],
    [2.00, -0.2812, 0.1390,  0.0171, 0.3898, 0.1297, 0.1297],
    [2.05, -0.2847, 0.1352,  0.0223, 0.3853, 0.1310, 0.1310],
    [2.10, -0.2879, 0.1316,  0.0272, 0.3811, 0.1323, 0.1323],
    [2.15, -0.2908, 0.1282,  0.0317, 0.3769, 0.1335, 0.1335],
    [2.20, -0.2934, 0.1251,  0.0359, 0.3730, 0.1347, 0.1347],
    [2.25, -0.2958, 0.1221,  0.0397, 0.3692, 0.1359, 0.1359],
    [2.30, -0.2980, 0.1193,  0.0432, 0.3655, 0.1370, 0.1370],
    [2.35, -0.3000, 0.1167,  0.0465, 0.3620, 0.1381, 0.1381],
    [2.40, -0.3018, 0.1142,  0.0495, 0.3586, 0.1392, 0.1392],
    [2.45, -0.3035, 0.1119,  0.0523, 0.3553, 0.1402, 0.1402],
    [2.50, -0.3051, 0.1098,  0.0549, 0.3521, 0.1412, 0.1412],
    [2.55, -0.3066, 0.1078,  0.0572, 0.3491, 0.1422, 0.1422],
    [2.60, -0.3079, 0.1059,  0.0594, 0.3461, 0.1432, 0.1432],
    [2.65, -0.3092, 0.1042,  0.0614, 0.3433, 0.1441, 0.1441],
    [2.70, -0.3104, 0.1026,  0.0632, 0.3406, 0.1450, 0.1450],
    [2.75, -0.3115, 0.1011,  0.0649, 0.3379, 0.1458, 0.1458],
    [2.80, -0.3125, 0.0997,  0.0665, 0.3354, 0.1467, 0.1467],
    [2.85, -0.3135, 0.0984,  0.0679, 0.3329, 0.1475, 0.1475]]



num_qubits = 2

lowest_energies = []
bond_distances = []
for i in range(len(raw_data_table_1)):
    # Use data of paper to construct the Hamiltonian
    bond_distances.append(raw_data_table_1[i][0])
    hamiltonian = raw_data_table_1[i][1] * QubitOperator(())  # == identity
    hamiltonian += raw_data_table_1[i][2] * QubitOperator("Z0")
    hamiltonian += raw_data_table_1[i][3] * QubitOperator("Z1")
    hamiltonian += raw_data_table_1[i][4] * QubitOperator("Z0 Z1")
    hamiltonian += raw_data_table_1[i][5] * QubitOperator("X0 X1")
    hamiltonian += raw_data_table_1[i][6] * QubitOperator("Y0 Y1")



    hamiltonian_norm = 0.
    for term in hamiltonian.terms:
        hamiltonian_norm += abs(hamiltonian.terms[term])
    normalized_hamiltonian = deepcopy(hamiltonian)
    normalized_hamiltonian /= hamiltonian_norm

    def get_eigenvalue_and_eigenvector(n_sites, hamiltonian, k, which='SA'):
        """
        Returns k eigenvalues and eigenvectors of the hamiltonian.

        Args:
            n_sites(int): Number of qubits/sites in the hamiltonian
            hamiltonian(QubitOperator): QubitOperator representating the Hamiltonian
            k: num of eigenvalue and eigenvector pairs (see spsl.eigsh k)
            which: see spsl.eigsh which

        """
        def mv(v):
            eng = projectq.MainEngine(backend=Simulator(), engine_list=[])
            #eng = MainEngine(backend = Simulator() , engine_list = get_engine_list() + [drawing_engine])
            qureg = eng.allocate_qureg(n_sites)
            eng.flush()
            eng.backend.set_wavefunction(v, qureg)
            eng.backend.apply_qubit_operator(hamiltonian, qureg)
            order, output = deepcopy(eng.backend.cheat())
            for i in order:
                assert i == order[i]
            eng.backend.set_wavefunction([1]+[0]*(2**n_sites-1), qureg)
            return output

        A = spsl.LinearOperator((2**n_sites,2**n_sites), matvec=mv)

        eigenvalues, eigenvectormatrix = spsl.eigsh(A, k=k, which=which)
        eigenvectors = []
        for i in range(k):
            eigenvectors.append(list(eigenvectormatrix[:, i]))
        return eigenvalues, eigenvectors


    eigenvalues, eigenvectors = get_eigenvalue_and_eigenvector(
        n_sites=num_qubits,
        hamiltonian=normalized_hamiltonian,
        k=1)
    print(eigenvalues)


    def W(eng, individual_terms, initial_wavefunction, ancilla_qubits, system_qubits):
        """
        Applies the W operator as defined in arXiv:1711.11025.

        Args:
            eng(MainEngine): compiler engine
            individual_terms(list<QubitOperator>): list of individual unitary
                                                   QubitOperators. It applies
                                                   individual_terms[0] if ancilla
                                                   qubits are in state |0> where
                                                   ancilla_qubits[0] is the least
                                                   significant bit.
            initial_wavefunction: Initial wavefunction of the ancilla qubits
            ancilla_qubits(Qureg): ancilla quantum register in state |0>
            system_qubits(Qureg): system quantum register
        """
        # Apply V:
        for ancilla_state in range(len(individual_terms)):
            with Compute(eng):
                for bit_pos in range(len(ancilla_qubits)):
                    if not (ancilla_state >> bit_pos) & 1:
                        X | ancilla_qubits[bit_pos]
            with Control(eng, ancilla_qubits):
                individual_terms[ancilla_state] | system_qubits
            Uncompute(eng)
        # Apply S: 1) Apply B^dagger
        with Compute(eng):
            with Dagger(eng):
                StatePreparation(initial_wavefunction) | ancilla_qubits
        # Apply S: 2) Apply I-2|0><0|
        with Compute(eng):
            All(X) | ancilla_qubits
        with Control(eng, ancilla_qubits[:-1]):
            Z | ancilla_qubits[-1]
        Uncompute(eng)
        # Apply S: 3) Apply B
        Uncompute(eng)
        # Could also be omitted and added when calculating the eigenvalues:
        Ph(math.pi) | system_qubits[0]

    eng = projectq.MainEngine()
    system_qubits = eng.allocate_qureg(num_qubits)

    # Create a normalized equal superposition of the two eigenstates for numerical testing:
    initial_state_norm = 0.
    initial_state = eigenvectors[0]
    for amplitude in initial_state:
        initial_state_norm += abs(amplitude)**2
    normalized_initial_state = [amp / math.sqrt(initial_state_norm) for amp in initial_state]

    #initialize system qubits in this state:
    StatePreparation(normalized_initial_state) | system_qubits


    individual_terms = []
    initial_ancilla_wavefunction = []
    for term in normalized_hamiltonian.terms:
        coefficient = normalized_hamiltonian.terms[term]
        initial_ancilla_wavefunction.append(math.sqrt(abs(coefficient)))
        if coefficient < 0:
            individual_terms.append(QubitOperator(term, -1))
        else:
            individual_terms.append(QubitOperator(term))

    # Calculate the number of ancilla qubits required and pad
    # the ancilla wavefunction with zeros:
    num_ancilla_qubits = int(math.ceil(math.log(len(individual_terms), 2)))
    required_padding = 2**num_ancilla_qubits - len(initial_ancilla_wavefunction)
    initial_ancilla_wavefunction.extend([0]*required_padding)

    # Initialize ancillas by applying B
    ancillas = eng.allocate_qureg(num_ancilla_qubits)
    StatePreparation(initial_ancilla_wavefunction) | ancillas
    
        
    lowest_energies.append(eng.backend.get_expectation_value(normalized_hamiltonian, system_qubits))


print(lowest_energies)
print(bond_distances)

plt.xlabel("Bond length [Angstrom]")
plt.ylabel("Total Energy [Hartree]")
plt.title("Spectrum by Quantum walk")
plt.plot(bond_distances, lowest_energies, "b.-",
         label="Ground-state energy of molecular hydrogen")
plt.legend()
plt.show()
#eng.backend.get_expectation_value(normalized_hamiltonian, system_qubits)
